# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Netflix Userbase.csv')

# %%
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
df.isna().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
df['User ID'].unique()
# Out:
# array([   1,    2,    3, ..., 2498, 2499, 2500], dtype=int64)

# %%
df['Subscription Type'].unique()
# Out:
# array(['Basic', 'Premium', 'Standard'], dtype=object)

# %%
df['Subscription Type'].value_counts()
# Out:
# Basic       999
# Standard    768
# Premium     733
# Name: Subscription Type, dtype: int64

# %%
sns.countplot(x = 'Subscription Type', data = df)
# Out:
# <Axes: xlabel='Subscription Type', ylabel='count'>

# %%
df['Subscription Type'].value_counts().plot(kind = 'pie' ,autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='Subscription Type'>

# %%
df['Monthly Revenue'].unique()
# Out:
# array([10, 15, 12, 13, 11, 14], dtype=int64)

# %%
df['Monthly Revenue'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='Monthly Revenue'>

# %%
sns.barplot(x = 'Monthly Revenue', y = 'Age', data = df )
# Out:
# <Axes: xlabel='Monthly Revenue', ylabel='Age'>

# %%
sns.barplot(x = 'Monthly Revenue' , y = 'Subscription Type', data = df)
# Out:
# <Axes: xlabel='Monthly Revenue', ylabel='Subscription Type'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'Country' , y = 'Monthly Revenue', data = df)
# Out:
# <Axes: xlabel='Country', ylabel='Monthly Revenue'>

# %%
sns.barplot(x = 'Gender' , y = 'Monthly Revenue', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='Monthly Revenue'>

# %%
df['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Australia',
#        'Germany', 'France', 'Brazil', 'Mexico', 'Spain', 'Italy'],
#       dtype=object)

# %%
df['Country'].value_counts()
# Out:
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: Country, dtype: int64

# %%
df['Country'].value_counts().plot(kind = 'pie' , autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Country'>

# %%
plt.figure(figsize= (12,5))
sns.barplot(x = 'Country', y = 'Age', data = df )
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.histplot(df['Country'])
plt.show()

# %%
df['Age'].unique()
# Out:
# array([28, 35, 42, 51, 33, 29, 46, 39, 37, 44, 31, 45, 48, 27, 38, 36, 30,
#        43, 32, 41, 26, 34, 49, 40, 47, 50], dtype=int64)

# %%
df['Age'].value_counts()
# Out:
# 39    116
# 30    116
# 28    115
# 31    115
# 41    114
# 47    111
# 37    107
# 35    105
# 29    104
# 40    103
# 42    102
# 48    101
# 46     99
# 36     99
# 49     97
# 43     94
# 33     93
# 51     93
# 32     92
# 45     89
# 38     89
# 34     88
# 27     87
# 44     86
# 50     84
# 26      1
# Name: Age, dtype: int64

# %%
df['Age'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='Age'>

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Female    1257
# Male      1243
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Device'].unique()
# Out:
# array(['Smartphone', 'Tablet', 'Smart TV', 'Laptop'], dtype=object)

# %%
df['Device'].value_counts()
# Out:
# Laptop        636
# Tablet        633
# Smartphone    621
# Smart TV      610
# Name: Device, dtype: int64

# %%
df['Device'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='Device'>

# %%
sns.barplot(x = 'Device', y = 'Age' , data = df)
# Out:
# <Axes: xlabel='Device', ylabel='Age'>

# %%
sns.countplot(x = 'Device', data = df)
# Out:
# <Axes: xlabel='Device', ylabel='count'>

# %%
df['Plan Duration'].unique()
# Out:
# array(['1 Month'], dtype=object)

# %%
df['Plan Duration'].value_counts()
# Out:
# 1 Month    2500
# Name: Plan Duration, dtype: int64

# %%
sns.countplot(x = 'Plan Duration', data = df)
# Out:
# <Axes: xlabel='Plan Duration', ylabel='count'>

# %%
Country_user = df.groupby("Country")["User ID"].count().reset_index()
Country_user
# Out:
#           Country  User ID
# 0       Australia      183
# 1          Brazil      183
# 2          Canada      317
# 3          France      183
# 4         Germany      183
# 5           Italy      183
# 6          Mexico      183
# 7           Spain      451
# 8  United Kingdom      183
# 9   United States      451

# %%
total_country_revenue = df.groupby("Country")["Monthly Revenue"].sum().reset_index()
total_country_revenue
# Out:
#           Country  Monthly Revenue
# 0       Australia             2271
# 1          Brazil             2285
# 2          Canada             3950
# 3          France             2307
# 4         Germany             2260
# 5           Italy             2317
# 6          Mexico             2237
# 7           Spain             5662
# 8  United Kingdom             2318
# 9   United States             5664

# %%
Country_revenue_by_age = df.groupby("Age")["Monthly Revenue"].sum().reset_index()
Country_revenue_by_age
# Out:
#     Age  Monthly Revenue
# 0    26               15
# 1    27             1101
# 2    28             1438
# 3    29             1317
# 4    30             1475
# 5    31             1413
# 6    32             1156
# 7    33             1161
# 8    34             1091
# 9    35             1325
# 10   36             1225
# 11   37             1326
# 12   38             1115
# 13   39             1460
# 14   40             1271
# 15   41             1447
# 16   42             1261
# 17   43             1190
# 18   44             1087
# 19   45             1127
# 20   46             1229
# 21   47             1406
# 22   48             1233
# 23   49             1214
# 24   50             1051
# 25   51             1137

# %%
Revenue_by_device = df.groupby("Device")["Monthly Revenue"].sum().reset_index()
Revenue_by_device
# Out:
#        Device  Monthly Revenue
# 0      Laptop             7994
# 1    Smart TV             7615
# 2  Smartphone             7691
# 3      Tablet             7971

# %%
Device = df.groupby('Device')['Age'].sum().reset_index()

# %%
Device
# Out:
#        Device    Age
# 0      Laptop  24827
# 1    Smart TV  23603
# 2  Smartphone  24049
# 3      Tablet  24510

# %%
Revenue_by_gender = df.groupby("Gender")["Monthly Revenue"].sum().reset_index()
Revenue_by_gender
# Out:
#    Gender  Monthly Revenue
# 0  Female            15736
# 1    Male            15535
